# %% [markdown]
# <a href="https://colab.research.google.com/github/vifirsanova/ML-2026-pt-2/blob/main/beginners/3_cnn/pandas_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Основы Pandas

# %% [markdown]
# Где учить: https://pandas.pydata.org/docs/user_guide/10min.html

# %%
# как создать DataFrame
# 1. создать python dictionary
# ключи словаря - это названия столбцов
# допустим, мы создаем корпус с транскрипцией слов
# 2. в каждый ключ мы заносим список
# туда пойдут значения, составляющие строки таблицы
# 3. все списки должны содержать одинаковое количество значений
# если мы что-то не можем заполнить, то подставляем NaN (пустое значение, "ничего")
import numpy as np
import pandas as pd

data = {
    'id': [0, 1, 2, 3, 4],
    'word': ['мопс', 'бульдог', 'кот', 'перец', 'расческа'],
    'ipa': [np.nan for x in range(5)],
}

data
# Out:
# {'id': [0, 1, 2, 3, 4],
#  'word': ['мопс', 'бульдог', 'кот', 'перец', 'расческа'],
#  'ipa': [nan, nan, nan, nan, nan]}

# %%
type(np.nan) # специальная заглужка для матричных вычислений массивов в numpy
# Out:
# float

# %% [markdown]
# Пример: создать DataFrame (таблицу) стоп-слов

# %% [markdown]
# 1. Выгрузим существующий список стоп-слов

# %% [markdown]
# - я ищу репозиторий со стоп-словами, например, https://github.com/stopwords-iso/stopwords-en
# - в файловой системе ищу что-то с *.txt
#
# ![image.png](data:image/png;base64,...)
#
#
# - открываю этот файл и ищу кнопку `Raw`
# - перехожу по ней и копирую ссылку в браузере

# %%
# по умолчанию файл сохранится в stopwords-en.txt
# но мы передаем параметр -O с названием data.txt

# !wget https://github.com/stopwords-iso/stopwords-en/raw/refs/heads/master/stopwords-en.txt -O data.txt
# Out:
# --2025-11-30 09:10:10--  https://github.com/stopwords-iso/stopwords-en/raw/refs/heads/master/stopwords-en.txt
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/stopwords-iso/stopwords-en/refs/heads/master/stopwords-en.txt [following]
# --2025-11-30 09:10:10--  https://raw.githubusercontent.com/stopwords-iso/stopwords-en/refs/heads/master/stopwords-en.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7677 (7.5K) [text/plain]
# Saving to: ‘data.txt’
#
# data.txt            100%[===================>]   7.50K  --.-KB/s    in 0s
#
# ...

# %%
with open('data.txt') as f:
    data = f.read().split('\n')

# %%
data[:10]
# Out:
# ["'ll", "'tis", "'twas", "'ve", '10', '39', 'a', "a's", 'able', 'ableabout']

# %% [markdown]
# 2. Создадим DataFrame вида: ID - стоп-слово

# %%
dataset = {
    'ID': [x for x in range(len(data))],
    'word': data,
}

# %%
dataset['ID'][4], dataset['word'][4]
# Out:
# (4, '10')

# %%
# когда словарь готов, можно сделать DataFrame

df = pd.DataFrame(dataset)
df.head()
# Out:
#    ID   word
# 0   0    'll
# 1   1   'tis
# 2   2  'twas
# 3   3    've
# 4   4     10

# %%
import pandas as pd

# Series - это один столбец с данными (как список с индексами)
fruits = pd.Series(['apple', 'banana', 'orange'], name='fruits')
print("Series:")
print(fruits)
print("\n")

# DataFrame - это таблица (как Excel), состоит из нескольких Series
data = {
    'name': ['Alice', 'Bob', 'Charlie'],
    'age': [25, 30, 35],
    'city': ['Moscow', 'London', 'Paris']
}

df = pd.DataFrame(data)
print("DataFrame:")
print(df)
# Out:
# Series:
# 0     apple
# 1    banana
# 2    orange
# Name: fruits, dtype: object
#
#
# DataFrame:
#       name  age    city
# 0    Alice   25  Moscow
# 1      Bob   30  London
# 2  Charlie   35   Paris

# %%
import numpy as np

pd.DataFrame(
    {
        'столбец 1': [1, 2, 3, 4],
        'столбец 2': [1, 2, 3, 4],
        'столбец 3': [1, 2, np.nan, 4],
    }
).dropna()
# Out:
#    столбец 1  столбец 2  столбец 3
# 0          1          1        1.0
# 1          2          2        2.0
# 3          4          4        4.0

# %%
df
# Out:
#       name  age    city
# 0    Alice   25  Moscow
# 1      Bob   30  London
# 2  Charlie   35   Paris
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_18.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %% [markdown]
# ## Поддержка Google Colab

# %%
df
# Out:
#       name  age    city
# 0    Alice   25  Moscow
# 1      Bob   30  London
# 2  Charlie   35   Paris
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['city'].value_counts()
    for x_label, grp in _df_11.groupby('name')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('name')
_ = plt.ylabel('city')

# %%
from matplotlib import pyplot as plt
_df_0['index'].plot(kind='hist', bins=20, title='index')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ## Чтение и запись

# %% [markdown]
# Примеры тестовых CSV-файлов: https://github.com/datablist/sample-csv-files?tab=readme-ov-file

# %%
# Читаем из CSV файла
df = pd.read_csv('customers-100.csv', encoding='utf-8-sig')
df.tail(5) # Первые 5 строк
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka       +1-846-706-2218
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        2022-01-30
# ...

# %%
df['City'].to_list() # создаем список из столбца
# Out:
# ['East Leonard',
#  'East Jimmychester',
#  'Isabelborough',
#  'Bensonview',
#  'West Priscilla',
#  'Chavezborough',
#  'Lake Ana',
#  'Kimport',
#  'Robersonstad',
#  'Elaineberg',
#  'Shannonville',
#  'East Andrea',
#  'South Joannamouth',
#  'Jodyberg',
#  'Burchbury',
#  'Desireeshire',
#  'West Adriennestad',
#  'Lake Leslie',
#  'Harmonview',
#  'Jamesshire',
#  'East Carly',
#  'South Alvin',
#  'Brittanyview',
#  'Veronicamouth',
#  'Bryanville',
#  'Kaitlyntown',
#  'Michealshire',
#  'South Marissatown',
#  'Acevedoville',
#  'North Harold',
#  'West Samuel',
#  'Cunninghamborough',
#  'Port Annatown',
#  'New Kaitlyn',
#  'West Marthaburgh',
#  'East Teresa',
#  'South Hunter',
#  'South Walter',
#  'Poolefurt',
#  'West John',
#  'West Darius',
#  'North Jimstad',
#  'East Rebekahborough',
#  'North Drew',
#  'Lake Lindaburgh',
#  'Gwendolynview',
#  'Zimmermanland',
#  'North Kerriton',
#  'North Eileenville',
#  'Port Sergiofort',
#  'New Alberttown',
# ...

# %% [markdown]
# ## Просмотр данных

# %%
# Просмотр данных
print("Первые 2 строки:")
print(df.head(2))

print("\nИнформация о данных:")
print(df.info())

print("\nОсновные статистики:")
print(df.describe())
# Out:
# Первые 2 строки:
#    Index      Customer Id First Name Last Name          Company  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter  Rasmussen Group
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano      Vega-Gentry
#
#                 City   Country       Phone 1           Phone 2  \
# 0       East Leonard     Chile  229.077.5154  397.884.0519x718
# 1  East Jimmychester  Djibouti    5153435776  686-620-1820x944
#
#                       Email Subscription Date                     Website
# 0  zunigavanessa@smith.info        2020-08-24  http://www.stephenson.com/
# 1           vmata@colon.com        2021-04-23       http://www.hobbs.com/
#
# Информация о данных:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    object
#  2   First Name         100 non-null    object
#  3   Last Name          100 non-null    object
#  4   Company            100 non-null    object
#  5   City               100 non-null    object
#  6   Country            100 non-null    object
#  7   Phone 1            100 non-null    object
#  8   Phone 2            100 non-null    object
#  9   Email              100 non-null    object
#  10  Subscription Date  100 non-null    object
#  11  Website            100 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.5+ KB

# %%
df.dropna()
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df['City'].head()
# Out:
# 0         East Leonard
# 1    East Jimmychester
# 2        Isabelborough
# 3           Bensonview
# 4       West Priscilla
# Name: City, dtype: object

# %%
df.iloc[0]
# Out:
# Index                                         1
# Customer Id                     DD37Cf93aecA6Dc
# First Name                               Sheryl
# Last Name                                Baxter
# Company                         Rasmussen Group
# City                               East Leonard
# Country                                   Chile
# Phone 1                            229.077.5154
# Phone 2                        397.884.0519x718
# Email                  zunigavanessa@smith.info
# Subscription Date                    2020-08-24
# Website              http://www.stephenson.com/
# Name: 0, dtype: object

# %%
df.iloc[0]['City']
# Out:
# 'East Leonard'

# %%
# Обращение к столбцам
print("Столбец с именами:")
print(df['First Name'].head())

print("\nСтолбец со странами:")
print(df['Country'].head())

# Обращение к строкам по индексу
print("\nПервая строка:")
print(df.iloc[0])

# Обращение к конкретной ячейке
print("\nИмя первого клиента:", df.iloc[0]['First Name'])
# Out:
# Столбец с именами:
# 0     Sheryl
# 1    Preston
# 2        Roy
# 3      Linda
# 4     Joanna
# Name: First Name, dtype: object
#
# Столбец со странами:
# 0                         Chile
# 1                      Djibouti
# 2           Antigua and Barbuda
# 3            Dominican Republic
# 4    Slovakia (Slovak Republic)
# Name: Country, dtype: object
#
# Первая строка:
# Index                                         1
# Customer Id                     DD37Cf93aecA6Dc
# First Name                               Sheryl
# Last Name                                Baxter
# Company                         Rasmussen Group
# City                               East Leonard
# Country                                   Chile
# Phone 1                            229.077.5154
# Phone 2                        397.884.0519x718
# Email                  zunigavanessa@smith.info
# Subscription Date                    2020-08-24
# Website              http://www.stephenson.com/
# Name: 0, dtype: object
# ...

# %% [markdown]
# ## Изменение и добавление данных

# %%
df['City Lower'] = df['City'].str.lower()
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
# Создаем новый столбец (длина имени)
df['Name Length'] = df['First Name'].str.len()

# Изменяем существующий столбец (приводим имена к верхнему регистру)
df['Surname Length'] = df['Last Name'].str.len()

# Создаем столбец с полным именем
df['Full Name'] = df['First Name'] + ' ' + df['Last Name']
full_name = 'Alice' + ' ' + 'Johns'

print("Добавлены новые столбцы:")
df[['First Name', 'Last Name', 'Full Name', 'Name Length', 'Surname Length']].head()
# Out:
# Добавлены новые столбцы:
#   First Name Last Name       Full Name  Name Length  Surname Length
# 0     Sheryl    Baxter   Sheryl Baxter            6               6
# 1    Preston    Lozano  Preston Lozano            7               6
# 2        Roy     Berry       Roy Berry            3               5
# 3      Linda     Olsen     Linda Olsen            5               5
# 4     Joanna    Bender   Joanna Bender            6               6

# %% [markdown]
# > Добавление новых данных на основе существующих в машинном обучении называется **feature engineering**

# %% [markdown]
# ## Фильтрация и захват частей данных

# %%
 df[['First Name', 'Last Name', 'Country', 'Subscription Date']]
# Out:
#    First Name Last Name                     Country Subscription Date
# 0      Sheryl    Baxter                       Chile        2020-08-24
# 1     Preston    Lozano                    Djibouti        2021-04-23
# 2         Roy     Berry         Antigua and Barbuda        2020-03-25
# 3       Linda     Olsen          Dominican Republic        2020-06-02
# 4      Joanna    Bender  Slovakia (Slovak Republic)        2021-04-17
# ..        ...       ...                         ...               ...
# 95       Karl     Greer                      Guyana        2022-01-30
# 96       Lynn  Atkinson                   Sri Lanka        2021-07-10
# 97       Fred    Guerra             Solomon Islands        2021-09-18
# 98     Yvonne    Farmer                       Aruba        2021-08-11
# 99   Clarence    Haynes                    Honduras        2020-03-11
#
# [100 rows x 4 columns]

# %%
# Фильтрация по условию (клиенты из США)
us_customers = df[df['Country'] == 'United States of America']
print("Клиенты из США:")
print(us_customers[['First Name', 'Last Name', 'City', 'Country']])

# Фильтрация по нескольким условиям
recent_customers = df[df['Subscription Date'] > '2022-01-01']
print(f"\nКлиенты после 2022-01-01: {len(recent_customers)} человек")

# Выбор конкретных столбцов
selected_columns = df[['First Name', 'Last Name', 'Country', 'Subscription Date']]
print("\nВыбранные столбцы:")
print(selected_columns.head())
# Out:
# Клиенты из США:
#    First Name Last Name         City                   Country
# 33    Kaitlyn   Santana  New Kaitlyn  United States of America
#
# Клиенты после 2022-01-01: 19 человек
#
# Выбранные столбцы:
#   First Name Last Name                     Country Subscription Date
# 0     Sheryl    Baxter                       Chile        2020-08-24
# 1    Preston    Lozano                    Djibouti        2021-04-23
# 2        Roy     Berry         Antigua and Barbuda        2020-03-25
# 3      Linda     Olsen          Dominican Republic        2020-06-02
# 4     Joanna    Bender  Slovakia (Slovak Republic)        2021-04-17

# %% [markdown]
# ## Редактирование текстовых данных

# %%
# Очистка телефонных номеров (удаляем всё кроме цифр)
df['Phone 1 Clean'] = df['Phone 1'].str.replace(r'\D', '', regex=True)
df['Phone 2 Clean'] = df['Phone 2'].str.replace(r'\D', '', regex=True)

# Извлекаем домен из email
df['Email Domain'] = df['Email'].str.split('@').str[1]

# Создаем категорию по длине имени
df['Name Category'] = df['Name Length'].apply(
    lambda x: 'Короткое' if x < 5 else 'Среднее' if x < 7 else 'Длинное'
) # https://www.w3schools.com/python/python_lambda.asp

df[['Phone 1', 'Phone 1 Clean', 'Email', 'Email Domain', 'Name Category']].head()
# Out:
#                   Phone 1       Phone 1 Clean                        Email  \
# 0            229.077.5154          2290775154     zunigavanessa@smith.info
# 1              5153435776          5153435776              vmata@colon.com
# 2         +1-539-402-0259         15394020259          beckycarr@hogan.com
# 3  001-808-617-6467x12895  001808617646712895  stanleyblackwell@benson.org
# 4  001-234-203-0635x76146  001234203063576146      colinalvarado@miles.net
#
#   Email Domain Name Category
# 0   smith.info       Среднее
# 1    colon.com       Длинное
# 2    hogan.com      Короткое
# 3   benson.org       Среднее
# 4    miles.net       Среднее

# %% [markdown]
# ## Анализ и статистика

# %%
# Статистика по странам
country_stats = df['Country'].value_counts()
print("Топ-5 стран по количеству клиентов:")
print(country_stats.head())

# Анализ по дате подписки
df['Subscription Year'] = pd.to_datetime(df['Subscription Date']).dt.year
yearly_subscriptions = df['Subscription Year'].value_counts().sort_index()

print("\nПодписки по годам:")
print(yearly_subscriptions)
# Out:
# Топ-5 стран по количеству клиентов:
# Country
# Solomon Islands       4
# Sri Lanka             2
# Oman                  2
# Togo                  2
# Dominican Republic    2
# Name: count, dtype: int64
#
# Подписки по годам:
# Subscription Year
# 2020    38
# 2021    43
# 2022    19
# Name: count, dtype: int64

# %% [markdown]
# - **dt** - работа с датами в pandas: `df['дата'].dt.year`, `.dt.month`, `.dt.day` для извлечения частей даты
#
# - **datetime** - модуль для работы с датами: `pd.to_datetime(df['столбец'])` преобразует текст в даты, `datetime.now()` - текущая дата-время
#
# - **value_counts** - подсчет уникальных значений: `df['столбец'].value_counts()` - возвращает частоту каждого значения, `normalize=True` для долей
#
# - **sort_index** - сортировка по индексу: `df.sort_index()` - по возрастанию, `ascending=False` - по убыванию. После groupby или для изменения порядка строк

# %% [markdown]
# ## Визуализация данных

# %%
# Настройка графиков
plt.figure(figsize=(15, 5))

# График 1: Распределение клиентов по странам (топ-10)
plt.subplot(1, 3, 1)
df['Country'].value_counts().head(10).plot(kind='bar', color='skyblue')
plt.title('Топ-10 стран по клиентам')
plt.xticks(rotation=45)

# График 2: Распределение длины имен
plt.subplot(1, 3, 2)
df['Name Length'].hist(bins=15, edgecolor='black', alpha=0.7)
plt.title('Распределение длины имен')
plt.xlabel('Длина имени')
plt.ylabel('Количество')

# График 3: Подписки по годам
plt.subplot(1, 3, 3)
yearly_subscriptions.plot(kind='line', marker='o', color='green')
plt.title('Подписки по годам')
plt.xlabel('Год')
plt.ylabel('Количество подписок')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Визуализация** - `df.plot()` для быстрых графиков или `import matplotlib.pyplot as plt` для кастомных. Основные типы: `kind='bar'`, `'line'`, `'hist'`

# %% [markdown]
# Документация seaborn: https://seaborn.pydata.org/index.html

# %% [markdown]
# Документация marplotlib: https://matplotlib.org/stable/index.html

# %% [markdown]
# ## Создание и сохранение новых таблиц

# %%
# Создаем таблицу с аналитикой по странам
country_analysis = df.groupby('Country').agg({
    'First Name': 'count',
    'Name Length': 'mean',
    'Subscription Date': 'min'
}).rename(columns={
    'First Name': 'Total Customers',
    'Name Length': 'Average Name Length',
    'Subscription Date': 'First Subscription'
}).round(2)

print("Аналитика по странам:")
print(country_analysis.head())

# Создаем таблицу контактов
contacts_table = df[['Full Name', 'Email', 'Phone 1 Clean', 'Country', 'Company']]
contacts_table = contacts_table.rename(columns={'Phone 1 Clean': 'Phone'})

print("\nТаблица контактов:")
print(contacts_table.head())
# Out:
# Аналитика по странам:
#                      Total Customers  Average Name Length First Subscription
# Country
# Albania                            1                  5.0         2021-04-06
# Algeria                            1                  6.0         2021-03-27
# Anguilla                           1                  6.0         2021-06-29
# Antigua and Barbuda                1                  3.0         2020-03-25
# Aruba                              1                  6.0         2021-08-11
#
# Таблица контактов:
#         Full Name                        Email               Phone  \
# 0   Sheryl Baxter     zunigavanessa@smith.info          2290775154
# 1  Preston Lozano              vmata@colon.com          5153435776
# 2       Roy Berry          beckycarr@hogan.com         15394020259
# 3     Linda Olsen  stanleyblackwell@benson.org  001808617646712895
# 4   Joanna Bender      colinalvarado@miles.net  001234203063576146
#
# ...

# %% [markdown]
# - **Groupby** - группировка данных по столбцам для агрегации (сумма, среднее, количество). Пример: `df.groupby('страна')['продажи'].sum()`
#
# - **agg** - применяет несколько агрегатных функций сразу: `df.agg({'столбец': ['mean', 'sum', 'count']})` или `df.groupby('x').agg({'y': 'sum', 'z': 'mean'})`

# %% [markdown]
# ## Сохранение результатов

# %%
# Сохраняем основную таблицу с дополнениями
df.to_csv('customers_enhanced.csv', index=False)

# Сохраняем таблицу контактов
contacts_table.to_csv('customer_contacts.csv', index=False)

# Сохраняем аналитику по странам
country_analysis.to_csv('country_analysis.csv', index=False)

# %%
df = pd.read_csv('country_analysis.csv')

# %%
# Показываем финальную структуру данных
print("Финальная структура данных:")
print(f"Размер: {df.shape}")
print(f"Столбцы: {list(df.columns)}")
# Out:
# Финальная структура данных:
# Размер: (85, 3)
# Столбцы: ['Total Customers', 'Average Name Length', 'First Subscription']

# %%
df
# Out:
#     Total Customers  Average Name Length First Subscription
# 0                 1                  5.0         2021-04-06
# 1                 1                  6.0         2021-03-27
# 2                 1                  6.0         2021-06-29
# 3                 1                  3.0         2020-03-25
# 4                 1                  6.0         2021-08-11
# ..              ...                  ...                ...
# 80                1                  8.0         2020-04-23
# 81                1                  5.0         2020-11-29
# 82                1                  8.0         2021-03-10
# 83                1                  6.0         2021-04-15
# 84                2                  5.5         2020-08-22
#
# [85 rows x 3 columns]

# %% [markdown]
# ## Туториал: Обработка текстовых данных с Pandas

# %% [markdown]
# ### Установка библиотек

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from collections import Counter

# %% [markdown]
# ### Создание датасета

# %%
# Создаем реалистичный датасет отзывов о продуктах
data = {
    'review_text': [
        "This product is absolutely amazing! The quality exceeded my expectations.",
        "Terrible customer service and the product arrived broken. Very disappointed.",
        "It's okay, nothing special. Does the job but I expected more features.",
        "The delivery was fast but the product quality is mediocre at best.",
        "Outstanding value for money! Will definitely buy again from this brand.",
        "Worst purchase ever. The item stopped working after 2 days.",
        "Good product with excellent features. The packaging was also very nice.",
        "Average product, average service. Nothing to complain about.",
        "The customer support team was very helpful and resolved my issue quickly!",
        "Product is good but the shipping took too long. Overall satisfied."
    ],
    'rating': [5, 1, 3, 2, 5, 1, 4, 3, 4, 3],
    'product_category': ['electronics', 'electronics', 'home', 'home', 'electronics',
                        'clothing', 'electronics', 'home', 'electronics', 'clothing'],
    'review_length': [58, 52, 43, 47, 51, 32, 48, 38, 62, 45]
}

df = pd.DataFrame(data)
print(f"Размер датасета: {df.shape}")
df.head()
# Out:
# Размер датасета: (10, 4)
#                                          review_text  rating product_category  \
# 0  This product is absolutely amazing! The qualit...       5      electronics
# 1  Terrible customer service and the product arri...       1      electronics
# 2  It's okay, nothing special. Does the job but I...       3             home
# 3  The delivery was fast but the product quality ...       2             home
# 4  Outstanding value for money! Will definitely b...       5      electronics
#
#    review_length
# 0             58
# 1             52
# 2             43
# 3             47
# 4             51

# %% [markdown]
# ### Операции и преобразования

# %%
# Просмотр информации о датасете
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   review_text       10 non-null     object
#  1   rating            10 non-null     int64
#  2   product_category  10 non-null     object
#  3   review_length     10 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#           rating  review_length
# count  10.000000      10.000000
# mean    3.100000      47.600000
# std     1.449138       8.884443
# min     1.000000      32.000000
# 25%     2.250000      43.500000
# 50%     3.000000      47.500000
# 75%     4.000000      51.750000
# max     5.000000      62.000000

# %%
# Анализ распределения рейтингов: продвинутое использование
df['rating'].value_counts().sort_index()
# Out:
# rating
# 1    2
# 2    1
# 3    3
# 4    2
# 5    2
# Name: count, dtype: int64

# %%
# Приведение к нижнему регистру
df['cleaned_text'] = df['review_text'].str.lower()

# Удаление пунктуации и специальных символов
df['cleaned_text'] = df['cleaned_text'].str.replace(r'[^\w\s]', '', regex=True)

# Удаление лишних пробелов
df['cleaned_text'] = df['cleaned_text'].str.strip()
df['cleaned_text'] = df['cleaned_text'].str.replace(r'\s+', ' ', regex=True)

# Показываем результаты
df[['review_text', 'cleaned_text']].head()
# Out:
#                                          review_text  \
# 0  This product is absolutely amazing! The qualit...
# 1  Terrible customer service and the product arri...
# 2  It's okay, nothing special. Does the job but I...
# 3  The delivery was fast but the product quality ...
# 4  Outstanding value for money! Will definitely b...
#
#                                         cleaned_text
# 0  this product is absolutely amazing the quality...
# 1  terrible customer service and the product arri...
# 2  its okay nothing special does the job but i ex...
# 3  the delivery was fast but the product quality ...
# 4  outstanding value for money will definitely bu...

# %% [markdown]
# ### Создание новых признаков

# %%
# Длина текста
df['text_length'] = df['cleaned_text'].str.len()

# Количество слов
df['word_count'] = df['cleaned_text'].str.split().str.len()

# Определение тональности по ключевым словам (простой подход)
def simple_sentiment(text):
    positive_words = ['amazing', 'outstanding', 'excellent', 'good', 'great', 'helpful', 'satisfied']
    negative_words = ['terrible', 'broken', 'disappointed', 'worst', 'mediocre']

    text_lower = text.lower()
    positive_score = sum(1 for word in positive_words if word in text_lower)
    negative_score = sum(1 for word in negative_words if word in text_lower)

    if positive_score > negative_score:
        return 'positive'
    elif negative_score > positive_score:
        return 'negative'
    else:
        return 'neutral'

df['simple_sentiment'] = df['cleaned_text'].apply(simple_sentiment)

df[['cleaned_text', 'text_length', 'word_count', 'simple_sentiment']].head()
# Out:
#                                         cleaned_text  text_length  word_count  \
# 0  this product is absolutely amazing the quality...           71          10
# 1  terrible customer service and the product arri...           74          10
# 2  its okay nothing special does the job but i ex...           66          12
# 3  the delivery was fast but the product quality ...           65          12
# 4  outstanding value for money will definitely bu...           69          11
#
#   simple_sentiment
# 0         positive
# 1         negative
# 2          neutral
# 3         negative
# 4         positive

# %% [markdown]
# ### Визуализация

# %%
# Настройка стиля графиков
sns.set_theme(style="whitegrid")
plt.figure(figsize=(15, 10))

# 1. Распределение рейтингов
plt.subplot(2, 3, 1)
df['rating'].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.title('Распределение рейтингов')
plt.xlabel('Рейтинг')
plt.ylabel('Количество')

# 2. Распределение длины текста
plt.subplot(2, 3, 2)
plt.hist(df['text_length'], bins=10, edgecolor='black', alpha=0.7)
plt.title('Распределение длины текста')
plt.xlabel('Длина текста')
plt.ylabel('Частота')

# 3. Распределение количества слов
plt.subplot(2, 3, 3)
sns.boxplot(x='rating', y='word_count', data=df)
plt.title('Количество слов по рейтингам')
plt.xlabel('Рейтинг')

# 4. Сентимент анализ
plt.subplot(2, 3, 4)
df['simple_sentiment'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightgreen', 'lightcoral', 'lightyellow'])
plt.title('Распределение тональности')

# 5. Распределение по категориям
plt.subplot(2, 3, 5)
df['product_category'].value_counts().plot(kind='bar', color='lightgreen')
plt.title('Распределение по категориям')
plt.xlabel('Категория')
plt.ylabel('Количество')

plt.tight_layout()
plt.show()

# %%
# ЗАДАНИЕ
new_reviews = [
    "Fantastic product with quick delivery! Highly recommended.",
    "The item was damaged upon arrival. Poor quality control.",
    "Decent product for the price. Met my basic expectations.",
    "Excellent customer service and fast shipping!",
    "Not what I expected. The product looks cheap."
]

# 1. Создать новый DataFrame с этими отзывами и их тональностью
# 2. Отобразить info и describe
# 3. Произвести чистку текста
# 4. Создать новые признаки
# 5. Создать одну любую визуализацию
